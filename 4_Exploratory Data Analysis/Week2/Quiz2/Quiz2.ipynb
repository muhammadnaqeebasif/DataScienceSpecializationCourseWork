# %% [markdown]
# # Q2

# %%
library(nlme)
library(lattice)
xyplot(weight ~ Time | Diet, BodyWeight)
# Out:
# plot without title

# %%
library(lattice)
library(datasets)
data(airquality)
p <- xyplot(Ozone ~ Wind | factor(Month), data = airquality)

# %% [markdown]
# # Q7

# %%
library(datasets)
library(ggplot2)
data(airquality)

# %%
qplot(Wind, Ozone, data = airquality, facets = . ~ factor(Month))
# Out:
# Warning message:
# "Removed 37 rows containing missing values (geom_point)."
# plot without title

# %%
airquality = transform(airquality, Month = factor(Month))
qplot(Wind, Ozone, data = airquality, facets = . ~ Month)
# Out:
# Warning message:
# "Removed 37 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# # Q9

# %%
install.packages("ggplot2movies",repos = "https://cran.ma.imperial.ac.uk/")
# Out:
# Installing package into 'C:/Users/naqee/Documents/R/win-library/3.4'
# (as 'lib' is unspecified)
# package 'ggplot2movies' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\naqee\AppData\Local\Temp\Rtmpo1Sqae\downloaded_packages

# %%
library(ggplot2)
library(ggplot2movies)
g <- ggplot(movies, aes(votes, rating))
print(g)
# Out:
# plot without title

# %%
qplot(votes, rating, data = movies) + geom_smooth()
# Out:
# `geom_smooth()` using method = 'gam'
# plot without title

# %%
qplot(votes, rating, data = movies) + stats_smooth("loess")
# Out:
# Error in stats_smooth("loess"): could not find function "stats_smooth"
# Traceback:
